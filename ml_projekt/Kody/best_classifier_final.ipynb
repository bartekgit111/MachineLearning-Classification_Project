# %% [markdown]
# ### Wstęp do Uczenia Maszynowego - Projekt
# ##### Bartosz Chudek 327426

# %% [markdown]
# ----

# %%
import joblib
import numpy as np
import pandas as pd

from model_tuner import model_tuner
from preprocessors import preprocessor_et

ensamble_models = joblib.load("all_ensamble_grids.pkl")

best_model = ensamble_models["et"]

X_test = pd.read_csv("data/artifical_test_data.csv")
X_train = pd.read_csv("data/artifical_train_data.csv")
y_train = np.ravel(pd.read_csv("data/artifical_train_labels.csv"))
y_train = (y_train == 1).astype(int)

# %%
best_pipeline = best_model[0]
best_et = best_pipeline.named_steps["model"]

# %% [markdown]
# ----
# ## Final results

# %%
best_et.get_params()
# Out:
# {'bootstrap': False,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'entropy',
#  'max_depth': 20,
#  'max_features': 0.5,
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'n_estimators': 150,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
print("Best_classifier final score:", best_model[1])
print("Best_classifier final std:", best_model[2])
# Out:
# Best_classifier final score: 0.872733
# Best_classifier final std: 0.029274

# %% [markdown]
# ### Prediction

# %%
best_pipeline.fit(X_train, y_train)
proba = best_pipeline.predict_proba(X_test)[:, 1]

np.savetxt("327426_artificial_prediction.txt",proba,fmt="%.6f")
